# %%
#Librerie
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson 
from statistics import median
from matplotlib import pyplot

# %% [markdown]
# ## Dati

# %% [markdown]
# ## Serie A

# %%
###########SERIEA###########
SEA = pd.read_html("https://fbref.com/it/comp/11/Serie-A-Seasons#results2022-2023111_home_away::1")
for idx,table in enumerate(SEA):
    print('********')
    idx
    table
SerieA = SEA[0]
SerieA



#"#############ATALANTA#############"
Ata = pd.read_html("https://fbref.com/it/squadre/922493f3/Statistiche-Atalanta#matchlogs_for")
for idx,table in enumerate(Ata):
    print('********')
    idx
    table
Atalanta = Ata[1]
Atalanta = Atalanta[Atalanta['Rf'].notna()]
Atalanta

#"############BOLOGNA####################"
Bol = pd.read_html("https://fbref.com/it/squadre/1d8099f8/Statistiche-Bologna#matchlogs_for")
for idx,table in enumerate(Bol):
    print('********')
    idx
    table
Bologna = Bol[1]
Bologna = Bologna[Bologna['Rf'].notna()]
Bologna

##############CREMONESE##############
Cre = pd.read_html("https://fbref.com/it/squadre/9aad3a77/Statistiche-Cremonese#matchlogs_for")
for idx,table in enumerate(Cre):
    print('********')
    idx
    table
Cremonese = Cre[1]
Cremonese = Cremonese[Cremonese['Rf'].notna()]
Cremonese

#############EMPOLI################
Emp = pd.read_html("https://fbref.com/it/squadre/a3d88bd8/Statistiche-Empoli#matchlogs_for")
for idx,table in enumerate(Emp):
    print('********')
    idx
    table
Empoli = Emp[1]
Empoli = Empoli[Empoli['Rf'].notna()]
Empoli

###########Fiorentina###############
Fio = pd.read_html("https://fbref.com/it/squadre/421387cf/Statistiche-Fiorentina#matchlogs_for")
for idx,table in enumerate(Fio):
    print('********')
    idx
    table
Fiorentina = Fio[1]
Fiorentina = Fiorentina[Fiorentina['Rf'].notna()]
Fiorentina

#Hellas Verona ################

Hve = pd.read_html("https://fbref.com/it/squadre/0e72edf2/Statistiche-Hellas-Verona#stats_standard_11")
for idx,table in enumerate(Hve):
    print('********')
    idx
    table
HellasVerona = Hve[1]
HellasVerona = HellasVerona[HellasVerona['Rf'].notna()]
HellasVerona


#########Inter############

Int = pd.read_html("https://fbref.com/it/squadre/d609edc0/Statistiche-Internazionale#stats_standard_11")
for idx,table in enumerate(Int):
    print('********')
    idx
    table
Inter = Int[1]
Inter = Inter[Inter['Rf'].notna()]
Inter

########Juventus##########

Juv = pd.read_html("https://fbref.com/it/squadre/e0652b02/Statistiche-Juventus#stats_standard_11")
for idx,table in enumerate(Juv):
    print('********')
    idx
    table
Juve = Juv[1]
Juve = Juve[Juve['Rf'].notna()]
Juve

###########Lazio############
Laz = pd.read_html("https://fbref.com/it/squadre/7213da33/Statistiche-Lazio#matchlogs_for")
for idx,table in enumerate(Laz):
    print('********')
    idx
    table
Lazio = Laz[1]
Lazio = Lazio[Lazio['Rf'].notna()]
Lazio


##########Lecce#############
Lec = pd.read_html("https://fbref.com/it/squadre/ffcbe334/Statistiche-Lecce#stats_standard_11")
for idx,table in enumerate(Lec):
    print('********')
    idx
    table
Lecce = Lec[1]
Lecce = Lecce[Lecce['Rf'].notna()]
Lecce

##########Milan#############
Mil = pd.read_html("https://fbref.com/it/squadre/dc56fe14/Statistiche-Milan#matchlogs_for")
for idx,table in enumerate(Mil):
    print('********')
    idx
    table
Milan = Mil[1]
Milan = Milan[Milan['Rf'].notna()]
Milan

##########Monza#############
Mon = pd.read_html("https://fbref.com/it/squadre/21680aa4/Statistiche-Monza#stats_standard_11")
for idx,table in enumerate(Mon):
    print('********')
    idx
    table
Monza = Mon[1]
Monza = Monza[Monza['Rf'].notna()]
Monza

#########Napoli################

Nap = pd.read_html("https://fbref.com/it/squadre/d48ad4ff/Statistiche-Napoli#stats_standard_11")
for idx,table in enumerate(Nap):
    print('********')
    idx
    table
Napoli = Nap[1]
Napoli = Napoli[Napoli['Rf'].notna()]
Napoli

########Roma##################
Rom = pd.read_html("https://fbref.com/it/squadre/cf74a709/Statistiche-Roma#matchlogs_for")
for idx,table in enumerate(Rom):
    print('********')
    idx
    table
Roma = Rom[1]
Roma = Roma[Roma['Rf'].notna()]
Roma

#########Salernitana############
Sal = pd.read_html("https://fbref.com/it/squadre/c5577084/Statistiche-Salernitana#stats_standard_11")
for idx,table in enumerate(Sal):
    print('********')
    idx
    table
Salernitana = Sal[1]
Salernitana = Salernitana[Salernitana['Rf'].notna()]
Salernitana

########Sampdoria############
Sam = pd.read_html("https://fbref.com/it/squadre/8ff9e3b3/Statistiche-Sampdoria#matchlogs_for")
for idx,table in enumerate(Sam):
    print('********')
    idx
    table
Sampdoria = Sam[1]
Sampdoria = Sampdoria[Sampdoria['Rf'].notna()]
Sampdoria

###########Sassuolo###########
Sas = pd.read_html("https://fbref.com/it/squadre/e2befd26/Statistiche-Sassuolo#stats_standard_11")
for idx,table in enumerate(Sas):
    print('********')
    idx
    table
Sassuolo = Sas[1]
Sassuolo = Sassuolo[Sassuolo['Rf'].notna()]
Sassuolo

######Spezia############

Spe = pd.read_html("https://fbref.com/it/squadre/68449f6d/Statistiche-Spezia#stats_standard_11")
for idx,table in enumerate(Spe):
    print('********')
    idx
    table
Spezia = Spe[1]
Spezia = Spezia[Spezia['Rf'].notna()]
Spezia

########Torino#########
Tor = pd.read_html("https://fbref.com/it/squadre/105360fe/Statistiche-Torino#stats_standard_11")
for idx,table in enumerate(Tor):
    print('********')
    idx
    table
Torino = Tor[1]
Torino = Torino[Torino['Rf'].notna()]
Torino


#######Udinese##########
Udi = pd.read_html("https://fbref.com/it/squadre/04eea015/Statistiche-Udinese#stats_standard_11")
for idx,table in enumerate(Udi):
    print('********')
    idx
    table
Udinese = Udi[1]
Udinese = Udinese[Udinese['Rf'].notna()]
Udinese
print('SerieA Upload!')

#PULIZIA DATASET
#pulizia dataset
x = Sampdoria['Rf']
x = x.replace('2 (9)', '2')
Sampdoria['Rf'] = pd.Series(x).astype(float)

y = Sampdoria['Rs']
y = y.replace('2 (8)', '2')
Sampdoria['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Cremonese['Rf']
x = x.replace('2 (5)', '2')
Cremonese['Rf'] = pd.Series(x).astype(float)

y = Cremonese['Rs']
y = y.replace('2 (4)', '2')
Cremonese['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Napoli['Rf']
x = x.replace('2 (4)', '2')
Napoli['Rf'] = pd.Series(x).astype(float)

y = Napoli['Rs']
y = y.replace('2 (5)', '2')
Napoli['Rs'] = pd.Series(y).astype(float)
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# SerieA Upload!
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:225: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sampdoria['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sampdoria['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:234: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cremonese['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Cremonese['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Napoli['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/604360288.py:247: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Napoli['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# ## Premier League

# %%
#######Arsenal##########
Ars = pd.read_html("https://fbref.com/it/squadre/18bb7c10/Statistiche-Arsenal#stats_standard_9")
for idx,table in enumerate(Ars):
    print('********')
    idx
    table
Arsenal = Ars[1]
Arsenal = Arsenal[Arsenal['Rf'].notna()]
Arsenal

######AstonVilla##########
Asv = pd.read_html("https://fbref.com/it/squadre/8602292d/Statistiche-Aston-Villa#stats_standard_9")
for idx,table in enumerate(Asv):
    print('********')
    idx
    table
AstonVilla = Asv[1]
AstonVilla = AstonVilla[AstonVilla['Rf'].notna()]
AstonVilla

############Bournemouth##########
Bou = pd.read_html("https://fbref.com/it/squadre/4ba7cbea/Statistiche-Bournemouth#stats_standard_9")
for idx,table in enumerate(Bou):
    print('********')
    idx
    table
Bournemouth = Bou[1]
Bournemouth = Bournemouth[Bournemouth['Rf'].notna()]


#########Brentford##################
Bre = pd.read_html("https://fbref.com/it/squadre/cd051869/Statistiche-Brentford#stats_standard_9")
for idx,table in enumerate(Bre):
    print('********')
    idx
    table
Brentford = Bre[1]
Brentford = Brentford[Brentford['Rf'].notna()]


#############Brighton#################
Bri = pd.read_html("https://fbref.com/it/squadre/d07537b9/Statistiche-Brighton-and-Hove-Albion#stats_standard_9")
for idx,table in enumerate(Bre):
    print('********')
    idx
    table
Brighton = Bri[1]
Brighton = Brighton[Brighton['Rf'].notna()]




##########Chelsea#############
Che = pd.read_html("https://fbref.com/it/squadre/cff3d9bb/Statistiche-Chelsea#stats_standard_9")
for idx,table in enumerate(Che):
    print('********')
    idx
    table
Chelsea = Che[1]
Chelsea = Chelsea[Chelsea['Rf'].notna()]


##########Crystal Palace############
Crp = pd.read_html("https://fbref.com/it/squadre/47c64c55/Statistiche-Crystal-Palace#stats_standard_9")
for idx,table in enumerate(Crp):
    print('********')
    idx
    table
CrystalPalace = Crp[1]
CrystalPalace = CrystalPalace[CrystalPalace['Rf'].notna()]


##Everton#########
Eve = pd.read_html("https://fbref.com/it/squadre/d3fd31cc/Statistiche-Everton#stats_standard_9")
for idx,table in enumerate(Eve):
    print('********')
    idx
    table
Everton = Eve[1]
Everton = Everton[Everton['Rf'].notna()]




#############Fulham##########
Ful = pd.read_html("https://fbref.com/it/squadre/fd962109/Statistiche-Fulham#stats_standard_9")
for idx,table in enumerate(Ful):
    print('********')
    idx
    table
Fulham = Ful[1]
Fulham = Fulham[Fulham['Rf'].notna()]



############LeedsUnited#########
Leu = pd.read_html("https://fbref.com/it/squadre/5bfb9659/Statistiche-Leeds-United#stats_standard_9")
for idx,table in enumerate(Leu):
    print('********')
    idx
    table
LeedsUnited = Leu[1]
LeedsUnited = LeedsUnited[LeedsUnited['Rf'].notna()]




########Leicester City###########
Lec = pd.read_html("https://fbref.com/it/squadre/a2d435b3/Statistiche-Leicester-City#stats_standard_9")
for idx,table in enumerate(Lec):
    print('********')
    idx
    table
LeicesterCity = Lec[1]
LeicesterCity = LeicesterCity[LeicesterCity['Rf'].notna()]


##############Liverpool
Liv = pd.read_html("https://fbref.com/it/squadre/822bd0ba/Statistiche-Liverpool#stats_standard_9")
for idx,table in enumerate(Liv):
    print('********')
    idx
    table
Liverpool = Liv[1]
Liverpool = Liverpool[Liverpool['Rf'].notna()]




###########ManchesterCity
Mac = pd.read_html("https://fbref.com/it/squadre/b8fd03ef/Statistiche-Manchester-City#stats_standard_9")
for idx,table in enumerate(Mac):
    print('********')
    idx
    table
ManchesterCity = Mac[1]
ManchesterCity = ManchesterCity[ManchesterCity['Rf'].notna()]


#Manchester Utd
Mau = pd.read_html("https://fbref.com/it/squadre/19538871/Statistiche-Manchester-United#stats_standard_9")
for idx,table in enumerate(Mau):
    print('********')
    idx
    table
ManchesterUtd = Mau[1]
ManchesterUtd = ManchesterUtd[ManchesterUtd['Rf'].notna()]


#Newcastle Utd
Neu = pd.read_html("https://fbref.com/it/squadre/b2b47a98/Statistiche-Newcastle-United#stats_standard_9")
for idx,table in enumerate(Neu):
    print('********')
    idx
    table
NewcastleUtd = Neu[1]
NewcastleUtd = NewcastleUtd[NewcastleUtd['Rf'].notna()]


#Nott'hamForest
Nof = pd.read_html("https://fbref.com/it/squadre/e4a775cb/Statistiche-Nottingham-Forest#stats_standard_9")
for idx,table in enumerate(Nof):
    print('********')
    idx
    table
NotthamForest = Nof[1]
NotthamForest = NotthamForest[NotthamForest['Rf'].notna()]


#Southampton
Sou = pd.read_html("https://fbref.com/it/squadre/33c895d4/Statistiche-Southampton#stats_standard_9")
for idx,table in enumerate(Sou):
    print('********')
    idx
    table
Southampton = Sou[1]
Southampton = Southampton[Southampton['Rf'].notna()]


#Tottenham
Tot = pd.read_html("https://fbref.com/it/squadre/361ca564/Statistiche-Tottenham-Hotspur#stats_standard_9")
for idx,table in enumerate(Tot):
    print('********')
    idx
    table
Tottenham = Sou[1]
Tottenham = Tottenham[Tottenham['Rf'].notna()]

#WestHam
Weh = pd.read_html("https://fbref.com/it/squadre/7c21e445/Statistiche-West-Ham-United#stats_standard_9")
for idx,table in enumerate(Weh):
    print('********')
    idx
    table
WestHam = Weh[1]
WestHam = WestHam[WestHam['Rf'].notna()]

#Wolves
Wel = pd.read_html("https://fbref.com/it/squadre/8cec06e1/Statistiche-Wolverhampton-Wanderers#stats_standard_9")
for idx,table in enumerate(Wel):
    print('********')
    idx
    table
Wolves = Wel[1]
Wolves = Wolves[Wolves['Rf'].notna()]

#pulizia dataset
x = Brighton['Rf']
x = x.replace('0 (3)', '0')
x = x.replace('0 (6)', '0')
Brighton['Rf'] = pd.Series(x).astype(float)

y = Brighton['Rs']
y = y.replace('0 (4)', '0')
y = y.replace('0 (7)', '0')
Brighton['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = NewcastleUtd['Rf']
x = x.replace('0 (3)', '0')
NewcastleUtd['Rf'] = pd.Series(x).astype(float)

y = NewcastleUtd['Rs']
y = y.replace('0 (2)', '0')
NewcastleUtd['Rs'] = pd.Series(y).astype(float)
#pulizia dataset
x = LeicesterCity['Rf']
x = x.replace('0 (3)', '0')
LeicesterCity['Rf'] = pd.Series(x).astype(float)

y = LeicesterCity['Rs']
y = y.replace('0 (1)', '0')
LeicesterCity['Rs'] = pd.Series(y).astype(float)
#pulizia dataset
x = Bournemouth['Rf']
x = x.replace('2 (5)', '2')
Bournemouth['Rf'] = pd.Series(x).astype(float)

y = Bournemouth['Rs']
y = y.replace('2 (3)', '2')
Bournemouth['Rs'] = pd.Series(y).astype(float)
#pulizia dataset
x = Brentford['Rf']
x = x.replace('1 (5)', '1')
Brentford['Rf'] = pd.Series(x).astype(float)

y = Brentford['Rs']
y = y.replace('1 (6)', '1')
Brentford['Rs'] = pd.Series(y).astype(float)
#pulizia dataset
x = Southampton['Rf']
x = x.replace('1 (6)', '1')
Southampton['Rf'] = pd.Series(x).astype(float)

y = Southampton['Rs']
y = y.replace('1 (5)', '1')
Southampton['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Liverpool['Rf']
x = x.replace('0 (3)', '0')
Liverpool['Rf'] = pd.Series(x).astype(float)

y = Liverpool['Rs']
y = y.replace('0 (2)', '0')
Liverpool['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = WestHam['Rf']
x = x.replace('2 (9)', '2')
WestHam['Rf'] = pd.Series(x).astype(float)

y = WestHam['Rs']
y = y.replace('2 (10)', '2')
WestHam['Rs'] = pd.Series(y).astype(float)
#pulizia dataset
x = CrystalPalace['Rf']
x = x.replace('0 (2)', '0')
CrystalPalace['Rf'] = pd.Series(x).astype(float)

y = CrystalPalace['Rs']
y = y.replace('0 (3)', '0')
CrystalPalace['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Tottenham['Rf']
x = x.replace('1 (6)', '1')
Tottenham['Rf'] = pd.Series(x).astype(float)

y = Tottenham['Rs']
y = y.replace('1 (5)', '1')
Tottenham['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Arsenal['Rf']
x = x.replace('1 (3)', '1')
Arsenal['Rf'] = pd.Series(x).astype(float)

y = Arsenal['Rs']
y = y.replace('1 (5)', '1')
Arsenal['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = Wolves['Rf']
x = x.replace('1 (3)', '1')
Wolves['Rf'] = pd.Series(x).astype(float)

y = Wolves['Rs']
y = y.replace('1 (4)', '1')
Wolves['Rs'] = pd.Series(y).astype(float)

#pulizia dataset
x = ManchesterUtd['Rf']
x = x.replace('0 (7)', '0')
ManchesterUtd['Rf'] = pd.Series(x).astype(float)

y = ManchesterUtd['Rs']
y = y.replace('0 (6)', '0')
ManchesterUtd['Rs'] = pd.Series(y).astype(float)


print("PremierLegue Upload!")
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# PremierLegue Upload!
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:211: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brighton['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:216: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brighton['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:221: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NewcastleUtd['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:225: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NewcastleUtd['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:229: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LeicesterCity['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LeicesterCity['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:237: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bournemouth['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:241: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Bournemouth['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brentford['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:249: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Brentford['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:253: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southampton['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:257: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Southampton['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liverpool['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:266: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Liverpool['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WestHam['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   WestHam['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:279: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CrystalPalace['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CrystalPalace['Rs'] = pd.Series(y).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tottenham['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/2019316651.py:292: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tottenham['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# ## La Liga

# %%
##Almería
Alm = pd.read_html("https://fbref.com/it/squadre/78ecf4bb/Statistiche-Almeria#stats_standard_12")
for idx,table in enumerate(Alm):
    print('********')
    idx
    table
Almeria = Alm[1]
Almeria = Almeria[Almeria['Rf'].notna()]


#Athletic Club
Ath = pd.read_html("https://fbref.com/it/squadre/2b390eca/Statistiche-Athletic-Club#stats_standard_12")
for idx,table in enumerate(Ath):
    print('********')
    idx
    table
AthleticClub = Ath[1]
AthleticClub = AthleticClub[AthleticClub['Rf'].notna()]

#Atlético Madrid
Atl = pd.read_html("https://fbref.com/it/squadre/db3b9613/Statistiche-Atletico-Madrid#stats_standard_12")
for idx,table in enumerate(Atl):
    print('********')
    idx
    table
AtleticoMadrid = Atl[1]
AtleticoMadrid = AtleticoMadrid[AtleticoMadrid['Rf'].notna()]

#Barcelona
Bar = pd.read_html("https://fbref.com/it/squadre/206d90db/Statistiche-Barcelona#stats_standard_12")
for idx,table in enumerate(Bar):
    print('********')
    idx
    table
Barcelona = Bar[1]
Barcelona = Barcelona[Barcelona['Rf'].notna()]

#Betis
Bet = pd.read_html("https://fbref.com/it/squadre/fc536746/Statistiche-Real-Betis#stats_standard_12")
for idx,table in enumerate(Bet):
    print('********')
    idx
    table
Betis = Bet[1]
Betis = Betis[Betis['Rf'].notna()]



#Cádiz
Cad = pd.read_html('https://fbref.com/it/squadre/ee7c297c/Statistiche-Cadiz#stats_standard_12')
for idx,table in enumerate(Cad):
    print('********')
    idx
    table
Cadiz = Cad[1]
Cadiz = Cadiz[Cadiz['Rf'].notna()]

#Celta Vigo
Cel = pd.read_html('https://fbref.com/it/squadre/f25da7fb/Statistiche-Celta-Vigo#stats_standard_12')
for idx,table in enumerate(Cel):
    print('********')
    idx
    table
CeltaVigo = Cel[1]
CeltaVigo = CeltaVigo[CeltaVigo['Rf'].notna()]


#Elche
Elc = pd.read_html('https://fbref.com/it/squadre/6c8b07df/Statistiche-Elche#stats_standard_12')
for idx,table in enumerate(Elc):
    print('********')
    idx
    table
Elche = Elc[1]
Elche = Elche[Elche['Rf'].notna()]


#Espanyol
Esp = pd.read_html('https://fbref.com/it/squadre/a8661628/Statistiche-Espanyol#stats_standard_12')
for idx,table in enumerate(Esp):
    print('********')
    idx
    table
Espanyol = Esp[1]
Espanyol = Espanyol[Espanyol['Rf'].notna()]


#Getafe
Get = pd.read_html('https://fbref.com/it/squadre/7848bd64/Statistiche-Getafe#stats_standard_12')
for idx,table in enumerate(Get):
    print('********')
    idx
    table
Getafe = Get[1]
Getafe = Getafe[Getafe['Rf'].notna()]

#Girona
Gir = pd.read_html('https://fbref.com/it/squadre/9024a00a/Statistiche-Girona#stats_standard_12')
for idx,table in enumerate(Gir):
    print('********')
    idx
    table
Girona = Gir[1]
Girona = Girona[Girona['Rf'].notna()]


#Mallorca
Mal = pd.read_html('https://fbref.com/it/squadre/2aa12281/Statistiche-Mallorca#stats_standard_12')
for idx,table in enumerate(Mal):
    print('********')
    idx
    table
Mallorca = Mal[1]
Mallorca = Mallorca[Mallorca['Rf'].notna()]

#Osasuna
Osa = pd.read_html('https://fbref.com/it/squadre/03c57e2b/Statistiche-Osasuna#stats_standard_12')
for idx,table in enumerate(Osa):
    print('********')
    idx
    table
Osasuna = Osa[1]
Osasuna = Osasuna[Osasuna['Rf'].notna()]

#Rayo Vallecano
Ray = pd.read_html('https://fbref.com/it/squadre/98e8af82/Statistiche-Rayo-Vallecano#stats_standard_12')
for idx,table in enumerate(Ray):
    print('********')
    idx
    table
RayoVallecano = Ray[1]
RayoVallecano = RayoVallecano[RayoVallecano['Rf'].notna()]


#Real Madrid
Rea = pd.read_html('https://fbref.com/it/squadre/53a2f082/Statistiche-Real-Madrid#stats_standard_12')
for idx,table in enumerate(Rea):
    print('********')
    idx
    table
RealMadrid = Rea[1]
RealMadrid = RealMadrid[RealMadrid['Rf'].notna()]

#Real Sociedad
Res = pd.read_html('https://fbref.com/it/squadre/e31d1cd9/Statistiche-Real-Sociedad#stats_standard_12')
for idx,table in enumerate(Res):
    print('********')
    idx
    table
RealSociedad = Res[1]
RealSociedad = RealSociedad[RealSociedad['Rf'].notna()]

#Sevilla
Sev = pd.read_html('https://fbref.com/it/squadre/ad2be733/Statistiche-Sevilla#stats_standard_12')
for idx,table in enumerate(Sev):
    print('********')
    idx
    table
Sevilla = Sev[1]
Sevilla = Sevilla[Sevilla['Rf'].notna()]

#Valencia
Val = pd.read_html('https://fbref.com/it/squadre/dcc91a7b/Statistiche-Valencia#stats_standard_12')
for idx,table in enumerate(Val):
    print('********')
    idx
    table
Valencia = Val[1]
Valencia = Valencia[Valencia['Rf'].notna()]

#Valladolid
Vad = pd.read_html('https://fbref.com/it/squadre/17859612/Statistiche-Valladolid#stats_standard_12')
for idx,table in enumerate(Vad):
    print('********')
    idx
    table
Valladolid = Vad[1]
Valladolid = Valladolid[Valladolid['Rf'].notna()]

#Villarreal
Vil = pd.read_html('https://fbref.com/it/squadre/2a8183b3/Statistiche-Villarreal#stats_standard_12')
for idx,table in enumerate(Vil):
    print('********')
    idx
    table
Villarreal = Vil[1]
Villarreal = Villarreal[Villarreal['Rf'].notna()]


print('LaLiga Update!')

# %% [markdown]
# ## LigueOne

# %%
##Ajaccio
Aja = pd.read_html("https://fbref.com/it/squadre/7a54bb4f/Statistiche-Ajaccio#stats_standard_13")
for idx,table in enumerate(Aja):
    print('********')
    idx
    table
Ajaccio = Aja[1]
Ajaccio = Ajaccio[Ajaccio['Rf'].notna()]


#Angers
Ang = pd.read_html("https://fbref.com/it/squadre/69236f98/Statistiche-Angers#stats_standard_13")
for idx,table in enumerate(Ang):
    print('********')
    idx
    table
Angers = Ang[1]
Angers = Angers[Angers['Rf'].notna()]

#Auxerre
Aux = pd.read_html("https://fbref.com/it/squadre/5ae09109/Statistiche-Auxerre#stats_standard_13")
for idx,table in enumerate(Aux):
    print('********')
    idx
    table
Auxerre = Aux[1]
Auxerre = Auxerre[Auxerre['Rf'].notna()]

#Brest
Bre = pd.read_html("https://fbref.com/it/squadre/fb08dbb3/Statistiche-Brest#stats_standard_13")
for idx,table in enumerate(Bre):
    print('********')
    idx
    table
Brest = Bre[1]
Brest = Brest[Brest['Rf'].notna()]

#Clermont
Cle = pd.read_html("https://fbref.com/it/squadre/d9676424/Statistiche-Clermont-Foot#stats_standard_13")
for idx,table in enumerate(Cle):
    print('********')
    idx
    table
Clermont = Cle[1]
Clermont = Clermont[Clermont['Rf'].notna()]

#Lens
Len = pd.read_html("https://fbref.com/it/squadre/fd4e0f7d/Statistiche-Lens#stats_standard_13")
for idx,table in enumerate(Len):
    print('********')
    idx
    table
Lens = Len[1]
Lens = Lens[Lens['Rf'].notna()]

#Lille
Lil = pd.read_html("https://fbref.com/it/squadre/cb188c0c/Statistiche-Lille#stats_standard_13")
for idx,table in enumerate(Lil):
    print('********')
    idx
    table
Lille = Lil[1]
Lille = Lille[Lille['Rf'].notna()]


#Lorient
Lor = pd.read_html("https://fbref.com/it/squadre/d2c87802/Statistiche-Lorient#stats_standard_13")
for idx,table in enumerate(Lor):
    print('********')
    idx
    table
Lorient = Lor[1]
Lorient = Lorient[Lorient['Rf'].notna()]


#Lyon
Lyo = pd.read_html("https://fbref.com/it/squadre/d53c0b06/Statistiche-Lyon#stats_standard_13")
for idx,table in enumerate(Lyo):
    print('********')
    idx
    table
Lyon = Lyo[1]
Lyon = Lyon[Lyon['Rf'].notna()]


#Marseille
Mar = pd.read_html('https://fbref.com/it/squadre/5725cc7b/Statistiche-Marseille#stats_standard_13')
for idx,table in enumerate(Mar):
    print('********')
    idx
    table
Marseille = Mar[1]
Marseille = Marseille[Marseille['Rf'].notna()]

#Monaco
Mon = pd.read_html("https://fbref.com/it/squadre/fd6114db/Statistiche-Monaco#stats_standard_13")
for idx,table in enumerate(Mon):
    print('********')
    idx
    table
Monaco = Mon[1]
Monaco = Monaco[Monaco['Rf'].notna()]


#Montpellier
Mon = pd.read_html('https://fbref.com/it/squadre/281b0e73/Statistiche-Montpellier#stats_standard_13')
for idx,table in enumerate(Mon):
    print('********')
    idx
    table
Montpellier = Mon[1]
Montpellier = Montpellier[Montpellier['Rf'].notna()]

#Nantes
Nan = pd.read_html('https://fbref.com/it/squadre/d7a486cd/Statistiche-Nantes#stats_standard_13')
for idx,table in enumerate(Nan):
    print('********')
    idx
    table
Nantes = Nan[1]
Nantes = Nantes[Nantes['Rf'].notna()]

#Nice
Nic = pd.read_html('https://fbref.com/it/squadre/132ebc33/Statistiche-Nice#stats_standard_13')
for idx,table in enumerate(Nic):
    print('********')
    idx
    table
Nice = Nic[1]
Nice = Nice[Nice['Rf'].notna()]


#Psg
Psg = pd.read_html('https://fbref.com/it/squadre/e2d8892c/Statistiche-Paris-Saint-Germain#stats_standard_13')
for idx,table in enumerate(Psg):
    print('********')
    idx
    table
PSG = Psg[1]
PSG = PSG[PSG['Rf'].notna()]

#Reims
Rei = pd.read_html('https://fbref.com/it/squadre/7fdd64e0/Statistiche-Reims#stats_standard_13')
for idx,table in enumerate(Rei):
    print('********')
    idx
    table
Reims = Rei[1]
Reims = Reims[Reims['Rf'].notna()]

#Rennes
Ren = pd.read_html('https://fbref.com/it/squadre/b3072e00/Statistiche-Rennes#stats_standard_13')
for idx,table in enumerate(Ren):
    print('********')
    idx
    table
Rennes = Ren[1]
Rennes = Rennes[Rennes['Rf'].notna()]

#Strasbourg
Str = pd.read_html('https://fbref.com/it/squadre/c0d3eab4/Statistiche-Strasbourg#stats_standard_13')
for idx,table in enumerate(Str):
    print('********')
    idx
    table
Strasbourg = Str[1]
Strasbourg = Strasbourg[Strasbourg['Rf'].notna()]

#Toulose
Tou = pd.read_html('https://fbref.com/it/squadre/3f8c4b5f/Statistiche-Toulouse#stats_standard_13')
for idx,table in enumerate(Tou):
    print('********')
    idx
    table
Toulose = Tou[1]
Toulose = Toulose[Toulose['Rf'].notna()]

#Troyes
Tro = pd.read_html('https://fbref.com/it/squadre/54195385/Statistiche-Troyes#stats_standard_13')
for idx,table in enumerate(Tro):
    print('********')
    idx
    table
Troyes = Tro[1]
Troyes = Troyes[Troyes['Rf'].notna()]

#pulizia dataset
x = Angers['Rf']
x = x.replace('1 (2)', '1')
x = x.replace('0 (5)', '0')
Angers['Rf'] = pd.Series(x).astype(float)

y = Angers['Rs']
y = y.replace('0 (4)', '0')
y = y.replace('1 (4)', '1')
Angers['Rs'] = pd.Series(y).astype(float)



print('Ligue One Update!')
# Out:
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-1aee7ee6a69b> in <module>
#      10
#      11 #Angers
# ---> 12 Ang = pd.read_html("https://fbref.com/it/squadre/69236f98/Statistiche-Angers#stats_standard_13")
#      13 for idx,table in enumerate(Ang):
#      14     print('********')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     891
#     892         try:
# --> 893             tables = p.parse_tables()
#     894         except ValueError as caught:
#     895             # if `io` is an io-like object, check if it's seekable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     712             if is_url(self.io):
#     713                 with urlopen(self.io) as f:
# --> 714                     r = parse(f, parser=parser)
#     715             else:
#     716                 # try to parse the input in the simplest way
#
# ~/opt/anaconda3/lib/python3.8/site-packages/lxml/html/__init__.py in parse(filename_or_url, parser, base_url, **kw)
#     937     if parser is None:
#     938         parser = html_parser
# --> 939     return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#     940
#     941
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseFilelikeDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFilelike()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/etree.pyx in lxml.etree._ExceptionContext._raise_if_stored()
#
# src/lxml/parser.pxi in lxml.etree._FileReaderContext.copyToBuffer()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     490
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#     494         if self.length is not None:
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _readinto_chunked(self, b)
#     585         try:
#     586             while True:
# --> 587                 chunk_left = self._get_chunk_left()
#     588                 if chunk_left is None:
#     589                     return total_bytes
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _get_chunk_left(self)
#     553                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     554             try:
# --> 555                 chunk_left = self._read_next_chunk_size()
#     556             except ValueError:
#     557                 raise IncompleteRead(b'')
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_next_chunk_size(self)
#     513     def _read_next_chunk_size(self):
#     514         # Read the next chunk size from the file
# --> 515         line = self.fp.readline(_MAXLINE + 1)
#     516         if len(line) > _MAXLINE:
#     517             raise LineTooLong("chunk size")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
Auxerre
# Out:
#           Data    Ora     Competizione          Girone Giorno  Stadio  \
# 0   07-08-2022  15:00          Ligue 1   Giornata n. 1    Dom  Ospiti
# 1   14-08-2022  15:00          Ligue 1   Giornata n. 2    Dom    Casa
# 2   21-08-2022  15:00          Ligue 1   Giornata n. 3    Dom  Ospiti
# 3   27-08-2022  17:00          Ligue 1   Giornata n. 4    Sab    Casa
# 4   31-08-2022  19:00          Ligue 1   Giornata n. 5    Mer  Ospiti
# 5   03-09-2022  17:00          Ligue 1   Giornata n. 6    Sab    Casa
# 6   11-09-2022  17:05          Ligue 1   Giornata n. 7    Dom  Ospiti
# 7   16-09-2022  21:00          Ligue 1   Giornata n. 8    Ven    Casa
# 8   02-10-2022  15:00          Ligue 1   Giornata n. 9    Dom    Casa
# 9   09-10-2022  15:00          Ligue 1  Giornata n. 10    Dom  Ospiti
# 10  16-10-2022  15:00          Ligue 1  Giornata n. 11    Dom    Casa
# 11  23-10-2022  15:00          Ligue 1  Giornata n. 12    Dom  Ospiti
# 12  30-10-2022  13:00          Ligue 1  Giornata n. 13    Dom    Casa
# 13  04-11-2022  21:00          Ligue 1  Giornata n. 14    Ven  Ospiti
# 14  13-11-2022  13:00          Ligue 1  Giornata n. 15    Dom  Ospiti
# 15  28-12-2022  17:00          Ligue 1  Giornata n. 16    Mer    Casa
# 16  01-01-2023  15:00          Ligue 1  Giornata n. 17    Dom  Ospiti
# 17  08-01-2023  18:00  Coupe de France     Round of 64    Dom  Ospiti
# 18  11-01-2023  19:00          Ligue 1  Giornata n. 18    Mer    Casa
# 19  14-01-2023  17:00          Ligue 1  Giornata n. 19    Sab  Ospiti
# 20  22-01-2023  18:30  Coupe de France     Round of 32    Dom  Ospiti
# 21  29-01-2023  15:00          Ligue 1  Giornata n. 20    Dom    Casa
# 22  01-02-2023  21:00          Ligue 1  Giornata n. 21    Mer  Ospiti
# 23  05-02-2023  15:00          Ligue 1  Giornata n. 22    Dom    Casa
# 24  08-02-2023  18:15  Coupe de France     Round of 16    Mer    Casa
# 25  12-02-2023  15:00          Ligue 1  Giornata n. 23    Dom  Ospiti
# 26  17-02-2023  21:00          Ligue 1  Giornata n. 24    Ven    Casa
# 27  26-02-2023  13:00          Ligue 1  Giornata n. 25    Dom  Ospiti
# 28  03-03-2023  21:00          Ligue 1  Giornata n. 26    Ven  Ospiti
# 29  11-03-2023  17:00          Ligue 1  Giornata n. 27    Sab    Casa
# 30  19-03-2023  15:00          Ligue 1  Giornata n. 28    Dom  Ospiti
# 31  01-04-2023  17:00          Ligue 1  Giornata n. 29    Sab    Casa
# 32  09-04-2023  15:00          Ligue 1  Giornata n. 30    Dom  Ospiti
# 33  16-04-2023  15:00          Ligue 1  Giornata n. 31    Dom    Casa
# 34  22-04-2023  17:00          Ligue 1  Giornata n. 32    Sab    Casa
# 35  30-04-2023  20:45          Ligue 1  Giornata n. 33    Dom  Ospiti
# 36  07-05-2023  15:00          Ligue 1  Giornata n. 34    Dom    Casa
# 37  14-05-2023  15:00          Ligue 1  Giornata n. 35    Dom  Ospiti
# 38  21-05-2023  20:45          Ligue 1  Giornata n. 36    Dom    Casa
#
#    Risultato     Rf     Rs     Avversario   xG  xGA  Poss.  Spettatori  \
# 0          P      1      4          Lille  0.6  2.4   41.0      32.292
# 1          N      2      2         Angers  0.8  1.4   40.0      15.577
# 2          V      2      1    Montpellier  1.3  1.0   36.0      13.137
# 3          V      1      0     Strasbourg  0.7  1.3   42.0      16.059
# 4          P      1      2           Lyon  0.7  2.6   38.0      38.609
# 5          P      0      2      Marseille  0.6  1.6   48.0      17.025
# 6          P      0      5         Rennes  0.7  1.6   52.0      27.837
# 7          P      1      3        Lorient  2.0  2.5   56.0      14.866
# 8          N      1      1          Brest  1.4  0.6   48.0      14.630
# 9          P      1      2  Clermont Foot  1.0  1.1   52.0      11.119
# 10         N      1      1           Nice  0.8  1.6   45.0      14.125
# 11         P      1      2          Reims  0.7  2.4   46.0      11.411
# 12         V      1      0        Ajaccio  1.5  0.4   41.0      15.092
# 13         N      1      1         Troyes  1.4  1.9   50.0      12.689
# 14         P      0      5      Paris S-G  0.7  2.0   41.0      45.000
# 15         P      2      3         Monaco  1.3  1.3   38.0      16.503
# 16         P      0      1         Nantes  0.8  1.0   50.0      23.266
# 17         N  2 (5)  2 (4)      Dunkerque  NaN  NaN   61.0       4.000
# 18         P      0      5       Toulouse  1.1  2.2   48.0      12.405
# 19         P      0      1           Lens  0.3  2.0   33.0      38.208
# 20         V      4      0          Niort  NaN  NaN   56.0       2.429
# 21         P      0      2    Montpellier  1.8  0.7   58.0      14.206
# 22         P      2      3         Monaco  1.4  1.2   56.0       3.561
# 23         N      0      0          Reims  1.2  0.6   40.0      14.680
# 24         P      2      3  Rodez Aveyron  NaN  NaN   65.0       5.322
# 25         N      1      1         Angers  2.6  0.9   50.0       7.873
# 26         V      2      1           Lyon  1.5  0.8   35.0      16.396
# 27         V      1      0        Lorient  0.7  1.5   39.0      13.089
# 28         N      1      1           Nice  0.5  1.6   36.0      21.133
# 29         N      0      0         Rennes  0.7  0.5   33.0      15.695
# 30         P      0      2     Strasbourg  0.7  2.8   49.0         NaN
# 31         V      1      0         Troyes  1.1  1.5   38.0         NaN
# 32         V      3      0        Ajaccio  0.8  1.1   43.0         NaN
# 33         V      2      1         Nantes  2.6  0.9   31.0         NaN
# 34         N      1      1          Lille  1.5  2.2   31.0      16.779
# 35         P      1      2      Marseille  0.5  2.6   31.0         NaN
# 36         N      1      1  Clermont Foot  1.2  1.5   47.0         NaN
# 37         P      0      1          Brest  0.6  1.6   55.0         NaN
# 38         P      1      2      Paris S-G  0.9  2.1   37.0         NaN
#
#         Capitano Formazione                  Arbitro  Report partita  \
# 0   Birama Touré    4-2-3-1          Eric Wattellier  Report partita
# 1   Birama Touré    4-1-4-1             Ruddy Buquet  Report partita
# 2   Birama Touré    4-1-4-1          Mathieu Vernice  Report partita
# 3   Birama Touré    4-1-4-1              Johan Hamel  Report partita
# 4   Birama Touré    4-1-4-1        Pierre Gaillouste  Report partita
# 5   Birama Touré    4-1-4-1            Willy Delajod  Report partita
# 6   Birama Touré    4-1-4-1           Thomas Léonard  Report partita
# 7   Birama Touré    4-1-4-1             Ruddy Buquet  Report partita
# 8   Birama Touré    4-1-4-1            Florent Batta  Report partita
# 9   Birama Touré    4-1-4-1          Mathieu Vernice  Report partita
# 10  Birama Touré    4-2-3-1          Eric Wattellier  Report partita
# 11  Birama Touré    4-2-3-1  Hakim Ben El Hadj Salem  Report partita
# 12  Birama Touré      4-4-2            Benoît Millot  Report partita
# 13  Birama Touré      4-4-2        Pierre Gaillouste  Report partita
# 14  Birama Touré      5-4-1           Thomas Léonard  Report partita
# 15  Birama Touré    4-4-1-1          Marc Bollengier  Report partita
# 16  Birama Touré    4-4-1-1           Benoît Bastien  Report partita
# 17  Birama Touré    3-4-1-2        François Letexier  Report partita
# 18  Birama Touré      4-4-2            Florent Batta  Report partita
# 19  Birama Touré      4-5-1            Willy Delajod  Report partita
# 20         Jubal      4-4-2             Ruddy Buquet  Report partita
# 21  Birama Touré      4-3-3            Jeremy Stinat  Report partita
# 22  Birama Touré      4-3-3          Eric Wattellier  Report partita
# 23  Birama Touré    4-2-3-1        Pierre Gaillouste  Report partita
# 24         Jubal      4-3-3       Stéphanie Frappart  Report partita
# 25  Birama Touré    4-2-3-1           Thomas Léonard  Report partita
# 26  Birama Touré      3-4-3           Jérôme Brisard  Report partita
# 27  Birama Touré      3-4-3            Benoît Millot  Report partita
# 28  Birama Touré      3-4-3          Bastien Dechepy  Report partita
# 29  Birama Touré      5-4-1          Mathieu Vernice  Report partita
# 30  Birama Touré      3-4-3          Eric Wattellier  Report partita
# 31  Birama Touré      3-4-3           Jérôme Brisard  Report partita
# 32  Birama Touré      3-4-3          Bastien Dechepy  Report partita
# 33  Birama Touré      3-4-3          Eric Wattellier  Report partita
# 34  Birama Touré      3-4-3       Stéphanie Frappart  Report partita
# 35  Birama Touré      3-4-3          Jérémie Pignard  Report partita
# 36  Birama Touré      3-4-3          Marc Bollengier  Report partita
# 37  Birama Touré      5-3-2          Eric Wattellier  Report partita
# 38  Birama Touré      5-4-1           Benoît Bastien  Report partita
#
#                                                  Note
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  Auxerre vince ai calci di rigore dopo i tempi ...
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN

# %%
# Out:
# <ipython-input-24-4400375d2aa2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Angers['Rf'] = pd.Series(x).astype(float)
# <ipython-input-24-4400375d2aa2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Angers['Rs'] = pd.Series(y).astype(float)

# %% [markdown]
# ## Bundersliga

# %%
"AUGSBURG" : "https://fbref.com/it/squadre/0cdc4311/Statistiche-Augsburg#stats_standard_20",
    "BAYERN MONACO" : "https://fbref.com/it/squadre/054efa67/Statistiche-Bayern-Munich#stats_standard_20",
    "BOCHUM" : "https://fbref.com/it/squadre/b42c6323/Statistiche-Bochum#stats_standard_20",
    "DORTMUND" : "https://fbref.com/it/squadre/add600ae/Statistiche-Dortmund#stats_standard_20",
    "EINTRACHT FRANCOFORTE" : "https://fbref.com/it/squadre/f0ac8ee6/Statistiche-Eintracht-Frankfurt#stats_standard_20",
    "FRIBURGO" : "https://fbref.com/it/squadre/a486e511/Statistiche-Freiburg#stats_standard_20",
    "HERTHA BSC" : "https://fbref.com/it/squadre/2818f8bc/Statistiche-Hertha-BSC#stats_standard_20",
    "HOFFENHEIM" : "https://fbref.com/it/squadre/033ea6b8/Statistiche-Hoffenheim#stats_standard_20",
    "KOLN" : "https://fbref.com/it/squadre/bc357bf7/Statistiche-Koln#stats_standard_20",
    "LEVERKUSEN" : "https://fbref.com/it/squadre/c7a9f859/Statistiche-Bayer-Leverkusen#stats_standard_20",
    "M GLADBACH" : "https://fbref.com/it/squadre/32f3ee20/Statistiche-Monchengladbach#stats_standard_20",
    "MAINZ 05" : "https://fbref.com/it/squadre/a224b06a/Statistiche-Mainz-05#stats_standard_20",
    "RB LIPSIA" : "https://fbref.com/it/squadre/acbb6a5b/Statistiche-RB-Leipzig#stats_standard_20",
    "SCHALKE 04" : "https://fbref.com/it/squadre/c539e393/Statistiche-Schalke-04#stats_standard_20",
    "STUTTGART" : "https://fbref.com/it/squadre/598bc722/Statistiche-Stuttgart#stats_standard_20",
    "UNION BERLINO" : "https://fbref.com/it/squadre/7a41008f/Statistiche-Union-Berlin#stats_standard_20",
    "WERDER BREMA" : "https://fbref.com/it/squadre/62add3bf/Statistiche-Werder-Bremen#stats_standard_20",
    "WOLFSBURG" : "https://fbref.com/it/squadre/4eaa11d7/Statistiche-Wolfsburg#stats_standard_20",

# %% [markdown]
# ## Funzione go

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

def go(data):
    # Seleziona le colonne che ti interessano come variabili predittive
    # e la colonna 'Gol' come variabile target
    features = data[['Rs','Poss.', 'Spettatori']]  # Sostituisci con le tue variabili predittive
    target = data['Rf']  # Sostituisci con la colonna dei gol realizzati della tua squadra

    # Dividi i dati in set di addestramento e di test
    X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.35, random_state=1234)

    # Crea un modello di regressione lineare
    model = LinearRegression()

    # Addestra il modello
    model.fit(X_train, y_train)

    # Valuta le prestazioni del modello sul set di test
    score = model.score(X_test, y_test)
    print('Score:', score)

    val1 = data['Rs'].median()
    val2 = data['Poss.'].median()
    val3 = data['Spettatori'].median()

    # Prevedi i gol realizzati da una squadra utilizzando nuovi dati
    new_data = pd.DataFrame([[val1, val2, val3]], columns=['Rs','Poss.', 'Spettatori'])  # Sostituisci con i tuoi valori
    predicted_goals = model.predict(new_data)

    print('Gol previsti:', predicted_goals)

    # Visualizza un grafico dei gol realizzati vs. gol previsti
    plt.scatter(y_test, model.predict(X_test))
    plt.xlabel('Gol realizzati')
    plt.ylabel('Gol previsti')
    plt.show()

# %%
#Funzione pulizia 
def pul(Squadra):
    sqpsubset = Squadra[['Rf', 'Rs', 'Poss.', 'Spettatori']]
    medianarf = sqpsubset['Rf'].median()
    medianars = sqpsubset['Rs'].median()
    medianaposs = sqpsubset['Poss.'].median()
    medianaspett = sqpsubset['Spettatori'].median()
    sqpsubset['Rf'].fillna(medianarf, inplace=True)
    sqpsubset['Rs'].fillna(medianars, inplace=True)
    sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
    sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
    return sqpsubset

# %%
def MP(Squadra):
    go(pul(Squadra))

# %% [markdown]
# ## Previsioni

# %% [markdown]
# ### Turno 36 Serie A

# %%
MP(Milan)
MP(Sampdoria)
# Out:
# Score: -0.084474079162971
# Gol previsti: [1.61232215]

# %%
MP(Lecce)
MP(Spezia)
# Out:
# Score: -1.4128065530354883
# Gol previsti: [0.82829601]

# %%
MP(Fiorentina)
MP(Torino)
# Out:
# Score: -0.4251441678593222
# Gol previsti: [1.56217265]
# Score: -0.009118636125154289
# Gol previsti: [1.39327373]

# %%
MP(Napoli)
MP(Inter)
# Out:
# Score: -0.1127192547242275
# Gol previsti: [2.35786851]

# %%
MP(Udinese)
MP(Lazio)
# Out:
# Score: -0.11312011065897232
# Gol previsti: [1.40944371]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
MP(Roma)
MP(Salernitana)
# Out:
# Score: -0.5132525960707242
# Gol previsti: [1.70736171]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
MP(Empoli)
MP(Juve)
# Out:
# Score: -0.5604598892511279
# Gol previsti: [1.06268669]

# %% [markdown]
# ### Turno 37 Premier League

# %%
MP(WestHam)
MP(LeedsUnited)
# Out:
# Score: 0.017414908612029323
# Gol previsti: [1.43868056]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# Score: 0.030976125650299835
# Gol previsti: [1.38208508]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
MP(Brighton)
MP(Southampton)
# Out:
# Score: -0.5644650049431117
# Gol previsti: [2.22129209]
# Score: 0.007852433768736566
# Gol previsti: [1.11813648]

# %%
MP(ManchesterCity)
MP(Chelsea)
# Out:
# Score: -0.3120238942119953
# Gol previsti: [2.61214546]
# Score: -0.007884733620144635
# Gol previsti: [1.08503324]

# %%
MP(NewcastleUtd)
MP(LeicesterCity)
# Out:
# Score: -0.22900606581186933
# Gol previsti: [1.67969482]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
# Score: -0.26153882275678475
# Gol previsti: [1.3860954]
# /Users/lucacefaloni/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
#Coppa Italia
MP(Fiorentina)
MP(Inter)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.35296798666559903
# Gol previsti: [1.78335184]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.267768138638907
# Gol previsti: [1.90691876]

# %% [markdown]
# ### Serie A turno 37

# %%
MP(Sampdoria)
MP(Sassuolo)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.33676503013408166
# Gol previsti: [0.81012092]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.03294756784489927
# Gol previsti: [1.03708702]

# %%
MP(Salernitana)
MP(Udinese)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.05222424103781509
# Gol previsti: [1.24998435]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.11255531719089862
# Gol previsti: [1.4094427]

# %%
MP(Spezia)
MP(Torino)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.10777192840759775
# Gol previsti: [0.83799098]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.016944975189751244
# Gol previsti: [1.35741936]

# %%
MP(Fiorentina)
MP(Roma)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.35296798666559903
# Gol previsti: [1.78335184]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.47611583101606314
# Gol previsti: [1.76474627]

# %%
MP(Inter)
MP(Atalanta)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.267768138638907
# Gol previsti: [1.90691876]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.0025392882793324745
# Gol previsti: [1.64806872]

# %%
MP(HellasVerona)
MP(Empoli)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.10477373654888811
# Gol previsti: [0.97720027]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.038466081469264224
# Gol previsti: [1.01147754]

# %%
MP(Bologna)
MP(Napoli)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.0020817812049784834
# Gol previsti: [1.36265704]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.2244101879713778
# Gol previsti: [2.20445717]

# %%
MP(Monza)
MP(Lecce)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.1139147510737396
# Gol previsti: [1.45392096]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -1.2611922981412236
# Gol previsti: [0.84550637]

# %%
MP(Lazio)
MP(Cremonese)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.25138917482736645
# Gol previsti: [1.60367239]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.001607814428352894
# Gol previsti: [0.82980658]

# %%
MP(Juve)
MP(Milan)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.45305056375387687
# Gol previsti: [1.55413128]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.4192831528654104
# Gol previsti: [1.11686276]

# %% [markdown]
# ### Premier League turno 38

# %%
MP(Chelsea)
MP(NewcastleUtd)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.009912529245094115
# Gol previsti: [1.07405589]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.039529236208493135
# Gol previsti: [1.53115056]

# %%
MP(AstonVilla)
MP(Brighton)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.016500735411117406
# Gol previsti: [1.49845793]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.3665186960355251
# Gol previsti: [2.1897889]

# %%
MP(Brentford)
MP(ManchesterCity)
# Out:
# Score: -0.06372764061023717
# Gol previsti: [1.95277081]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.425904480820152
# Gol previsti: [2.31090071]

# %%
MP(Arsenal)
MP(Wolves)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.37280972921647715
# Gol previsti: [2.2608291]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.7892344502123776
# Gol previsti: [0.87893049]

# %%
MP(ManchesterUtd)
MP(Fulham)
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: 0.06557338878964147
# Gol previsti: [1.85266119]
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rf'].fillna(medianarf, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Rs'].fillna(medianars, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Poss.'].fillna(medianaposs, inplace=True)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/3535765156.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sqpsubset['Spettatori'].fillna(medianaspett, inplace=True)
# Score: -0.29824246911807273
# Gol previsti: [1.69468308]

# %%
ManchesterUtd
# Out:
#           Data    Ora    Competizione  \
# 0   07-08-2022  14:00  Premier League
# 1   13-08-2022  17:30  Premier League
# 2   22-08-2022  20:00  Premier League
# 3   27-08-2022  12:30  Premier League
# 4   01-09-2022  20:00  Premier League
# 5   04-09-2022  16:30  Premier League
# 6   08-09-2022  20:00       Europa Lg
# 7   15-09-2022  19:45       Europa Lg
# 8   02-10-2022  14:00  Premier League
# 9   06-10-2022  19:45       Europa Lg
# 10  09-10-2022  19:00  Premier League
# 11  13-10-2022  20:00       Europa Lg
# 12  16-10-2022  14:00  Premier League
# 13  19-10-2022  20:15  Premier League
# 14  22-10-2022  17:30  Premier League
# 15  27-10-2022  20:00       Europa Lg
# 16  30-10-2022  16:15  Premier League
# 17  03-11-2022  18:45       Europa Lg
# 18  06-11-2022  14:00  Premier League
# 19  10-11-2022  20:00         EFL Cup
# 20  13-11-2022  16:30  Premier League
# 21  21-12-2022  20:00         EFL Cup
# 22  27-12-2022  20:00  Premier League
# 23  31-12-2022  12:30  Premier League
# 24  03-01-2023  20:00  Premier League
# 25  06-01-2023  20:00          FA Cup
# 26  10-01-2023  20:00         EFL Cup
# 27  14-01-2023  12:30  Premier League
# 28  18-01-2023  20:00  Premier League
# 29  22-01-2023  16:30  Premier League
# 30  25-01-2023  20:00         EFL Cup
# 31  28-01-2023  20:00          FA Cup
# 32  01-02-2023  20:00         EFL Cup
# 33  04-02-2023  15:00  Premier League
# 34  08-02-2023  20:00  Premier League
# 35  12-02-2023  14:00  Premier League
# 36  16-02-2023  18:45       Europa Lg
# 37  19-02-2023  14:00  Premier League
# 38  23-02-2023  20:00       Europa Lg
# 39  26-02-2023  16:30         EFL Cup
# 40  01-03-2023  19:45          FA Cup
# 41  05-03-2023  16:30  Premier League
# 42  09-03-2023  20:00       Europa Lg
# 43  12-03-2023  14:00  Premier League
# 44  16-03-2023  18:45       Europa Lg
# 45  19-03-2023  16:30          FA Cup
# 46  02-04-2023  16:30  Premier League
# 47  05-04-2023  20:00  Premier League
# 48  08-04-2023  12:30  Premier League
# 49  13-04-2023  20:00       Europa Lg
# 50  16-04-2023  16:30  Premier League
# 51  20-04-2023  21:00       Europa Lg
# 52  23-04-2023  16:30          FA Cup
# 53  27-04-2023  20:15  Premier League
# 54  30-04-2023  14:00  Premier League
# 55  04-05-2023  20:00  Premier League
# 56  07-05-2023  19:00  Premier League
# 57  13-05-2023  15:00  Premier League
# 58  20-05-2023  15:00  Premier League
#
#                                        Girone Giorno        Stadio Risultato  \
# 0                               Giornata n. 1    Dom          Casa         P
# 1                               Giornata n. 2    Sab        Ospiti         P
# 2                               Giornata n. 3    Lun          Casa         V
# 3                               Giornata n. 4    Sab        Ospiti         V
# 4                               Giornata n. 5    Gio        Ospiti         V
# 5                               Giornata n. 6    Dom          Casa         V
# 6                               Fase a gironi    Gio          Casa         P
# 7                               Fase a gironi    Gio        Ospiti         V
# 8                               Giornata n. 9    Dom        Ospiti         P
# 9                               Fase a gironi    Gio        Ospiti         V
# 10                             Giornata n. 10    Dom        Ospiti         V
# 11                              Fase a gironi    Gio          Casa         V
# 12                             Giornata n. 11    Dom          Casa         N
# 13                             Giornata n. 12    Mer          Casa         V
# 14                             Giornata n. 13    Sab        Ospiti         N
# 15                              Fase a gironi    Gio          Casa         V
# 16                             Giornata n. 14    Dom          Casa         V
# 17                              Fase a gironi    Gio        Ospiti         V
# 18                             Giornata n. 15    Dom        Ospiti         P
# 19                                Terzo turno    Gio          Casa         V
# 20                             Giornata n. 16    Dom        Ospiti         V
# 21                                   4° turno    Mer          Casa         V
# 22                             Giornata n. 17    Mar          Casa         V
# 23                             Giornata n. 18    Sab        Ospiti         V
# 24                             Giornata n. 19    Mar          Casa         V
# 25                 Terzo turno di fase finale    Ven          Casa         V
# 26                           Quarti di finale    Mar          Casa         V
# 27                             Giornata n. 20    Sab          Casa         V
# 28                              Giornata n. 7    Mer        Ospiti         N
# 29                             Giornata n. 21    Dom        Ospiti         P
# 30                                 Semifinali    Mer        Ospiti         V
# 31                Quarto turno di fase finale    Sab          Casa         V
# 32                                 Semifinali    Mer          Casa         V
# 33                             Giornata n. 22    Sab          Casa         V
# 34                              Giornata n. 8    Mer          Casa         N
# 35                             Giornata n. 23    Dom        Ospiti         V
# 36  Play-off con turno a eliminazione diretta    Gio        Ospiti         N
# 37                             Giornata n. 24    Dom          Casa         V
# 38  Play-off con turno a eliminazione diretta    Gio          Casa         V
# 39                                     Finale    Dom          Casa         V
# 40                Quinto turno di fase finale    Mer          Casa         V
# 41                             Giornata n. 26    Dom        Ospiti         P
# 42                           Ottavi di finale    Gio          Casa         V
# 43                             Giornata n. 27    Dom          Casa         N
# 44                           Ottavi di finale    Gio        Ospiti         V
# 45                           Quarti di finale    Dom          Casa         V
# 46                             Giornata n. 29    Dom        Ospiti         P
# 47                             Giornata n. 25    Mer          Casa         V
# 48                             Giornata n. 30    Sab          Casa         V
# 49                           Quarti di finale    Gio          Casa         N
# 50                             Giornata n. 31    Dom        Ospiti         V
# 51                           Quarti di finale    Gio        Ospiti         P
# 52                                 Semifinali    Dom  Campo neutro         N
# 53                             Giornata n. 33    Gio        Ospiti         N
# 54                             Giornata n. 34    Dom          Casa         V
# 55                             Giornata n. 28    Gio        Ospiti         P
# 56                             Giornata n. 35    Dom        Ospiti         P
# 57                             Giornata n. 36    Sab          Casa         V
# 58                             Giornata n. 37    Sab        Ospiti         V
#
#        Rf     Rs           Avversario   xG  xGA  Poss.  Spettatori  \
# 0       1      2             Brighton  1.4  1.5   62.0      73.711
# 1       0      4            Brentford  0.9  1.6   66.0      17.051
# 2       2      1            Liverpool  1.8  1.3   30.0      74.147
# 3       1      0          Southampton  1.1  1.4   51.0      31.196
# 4       1      0       Leicester City  1.5  0.7   47.0      32.226
# 5       3      1              Arsenal  1.5  1.3   40.0      73.431
# 6       0      1     es Real Sociedad  0.8  1.1   55.0      74.310
# 7       2      0  md Sheriff Tiraspol  1.6  0.3   68.0       8.734
# 8       3      6      Manchester City  1.7  3.2   47.0      53.475
# 9       3      2         cy AC Omonia  3.1  1.2   73.0      20.011
# 10      2      1              Everton  1.4  0.6   60.0      39.258
# 11      1      0         cy AC Omonia  4.2  0.1   78.0      74.310
# 12      0      0        Newcastle Utd  0.8  0.8   63.0      73.726
# 13      2      0            Tottenham  1.5  0.6   52.0      73.677
# 14      1      1              Chelsea  0.8  1.1   52.0      39.503
# 15      3      0  md Sheriff Tiraspol  2.7  0.0   74.0      73.764
# 16      1      0             West Ham  1.2  1.1   53.0      73.682
# 17      1      0     es Real Sociedad  0.7  1.1   53.0      36.744
# 18      1      3          Aston Villa  0.5  0.6   58.0      42.058
# 19      4      2          Aston Villa  NaN  NaN   59.0      72.512
# 20      2      1               Fulham  2.5  1.4   47.0      24.246
# 21      2      0              Burnley  NaN  NaN   55.0      62.062
# 22      3      0      Nott'ham Forest  2.4  0.7   65.0      73.608
# 23      1      0               Wolves  2.0  0.7   54.0      31.658
# 24      3      0          Bournemouth  2.2  0.6   58.0      73.322
# 25      3      1              Everton  NaN  NaN   58.0      72.306
# 26      3      0         Charlton Ath  NaN  NaN   69.0      74.345
# 27      2      1      Manchester City  1.7  0.6   30.0      75.546
# 28      1      1       Crystal Palace  2.1  0.5   60.0      23.343
# 29      2      3              Arsenal  0.4  3.1   43.0      60.325
# 30      3      0      Nott'ham Forest  NaN  NaN   67.0      29.325
# 31      3      1              Reading  NaN  NaN   78.0      73.460
# 32      2      0      Nott'ham Forest  NaN  NaN   74.0      72.315
# 33      2      1       Crystal Palace  2.0  1.3   52.0      73.420
# 34      2      2         Leeds United  2.0  0.6   66.0      73.456
# 35      2      0         Leeds United  1.1  1.8   66.0      36.919
# 36      2      2         es Barcelona  2.1  1.0   40.0      90.225
# 37      3      0       Leicester City  4.4  1.6   57.0      73.578
# 38      2      1         es Barcelona  1.1  1.2   43.0      73.021
# 39      2      0        Newcastle Utd  NaN  NaN   39.0      87.306
# 40      3      1             West Ham  NaN  NaN   60.0      72.571
# 41      0      7            Liverpool  0.8  2.8   41.0      53.001
# 42      4      1             es Betis  3.0  0.5   56.0      72.998
# 43      0      0          Southampton  0.8  1.0   47.0      73.439
# 44      1      0             es Betis  1.9  1.2   54.0      54.643
# 45      3      1               Fulham  NaN  NaN   56.0      73.511
# 46      0      2        Newcastle Utd  0.4  3.7   54.0      52.268
# 47      1      0            Brentford  1.2  0.7   64.0      73.309
# 48      2      0              Everton  3.4  1.0   63.0      73.509
# 49      2      2           es Sevilla  1.7  0.6   55.0      72.825
# 50      2      0      Nott'ham Forest  3.5  0.7   68.0      29.435
# 51      0      3           es Sevilla  1.0  2.0   61.0      41.974
# 52  0 (7)  0 (6)             Brighton  NaN  NaN   39.0      81.445
# 53      2      2            Tottenham  2.0  2.5   60.0      61.586
# 54      1      0          Aston Villa  1.2  0.6   57.0      73.592
# 55      0      1             Brighton  1.4  2.3   41.0      31.577
# 56      0      1             West Ham  1.2  1.3   65.0      62.477
# 57      2      0               Wolves  3.2  0.3   48.0      73.570
# 58      1      0          Bournemouth  1.4  1.0   59.0      10.240
#
#                          Capitano Formazione                  Arbitro  \
# 0                   Harry Maguire      4-3-3             Paul Tierney
# 1                   Harry Maguire    4-2-3-1           Stuart Attwell
# 2   Bruno Miguel Borges Fernandes    4-2-3-1           Michael Oliver
# 3   Bruno Miguel Borges Fernandes    4-2-3-1              Andy Madley
# 4   Bruno Miguel Borges Fernandes    4-2-3-1             Craig Pawson
# 5   Bruno Miguel Borges Fernandes    4-2-3-1             Paul Tierney
# 6                   Harry Maguire    4-2-3-1           Marco Di Bello
# 7   Bruno Miguel Borges Fernandes    4-2-3-1         Paweł Raczkowski
# 8   Bruno Miguel Borges Fernandes    4-2-3-1           Michael Oliver
# 9   Bruno Miguel Borges Fernandes    4-2-3-1            João Pinheiro
# 10  Bruno Miguel Borges Fernandes    4-2-3-1              David Coote
# 11  Bruno Miguel Borges Fernandes    4-2-3-1           Jérôme Brisard
# 12  Bruno Miguel Borges Fernandes    4-2-3-1             Craig Pawson
# 13  Bruno Miguel Borges Fernandes    4-2-3-1             Simon Hooper
# 14  Bruno Miguel Borges Fernandes    4-1-4-1           Stuart Attwell
# 15  Bruno Miguel Borges Fernandes    4-2-3-1  Anastasios Sidiropoulos
# 16                  Harry Maguire    4-2-3-1           Chris Kavanagh
# 17  Bruno Miguel Borges Fernandes    4-2-3-1           Georgi Kabakov
# 18              Cristiano Ronaldo    4-2-3-1           Anthony Taylor
# 19                  Harry Maguire    4-2-3-1              David Coote
# 20  Bruno Miguel Borges Fernandes    4-2-3-1             Paul Tierney
# 21  Bruno Miguel Borges Fernandes    4-2-3-1             Graham Scott
# 22  Bruno Miguel Borges Fernandes    4-2-3-1           Anthony Taylor
# 23  Bruno Miguel Borges Fernandes    4-2-3-1             Robert Jones
# 24                  Harry Maguire    4-2-3-1        Michael Salisbury
# 25  Bruno Miguel Borges Fernandes    4-2-3-1           Darren England
# 26                  Harry Maguire    4-2-3-1           Jarred Gillett
# 27  Bruno Miguel Borges Fernandes    4-2-3-1           Stuart Attwell
# 28  Bruno Miguel Borges Fernandes    4-2-3-1             Robert Jones
# 29  Bruno Miguel Borges Fernandes    4-2-3-1           Anthony Taylor
# 30  Bruno Miguel Borges Fernandes    4-2-3-1           Michael Oliver
# 31                  Harry Maguire    4-2-3-1           Darren England
# 32  Bruno Miguel Borges Fernandes      4-3-3             Peter Bankes
# 33  Bruno Miguel Borges Fernandes    4-2-3-1           Andre Marriner
# 34  Bruno Miguel Borges Fernandes    4-2-3-1             Simon Hooper
# 35                  Harry Maguire    4-2-3-1             Paul Tierney
# 36                  Wout Weghorst    4-1-4-1         Maurizio Mariani
# 37  Bruno Miguel Borges Fernandes    4-2-3-1           Stuart Attwell
# 38  Bruno Miguel Borges Fernandes    4-2-3-1           Clément Turpin
# 39  Bruno Miguel Borges Fernandes    4-2-3-1              David Coote
# 40                  Harry Maguire      4-3-3        Michael Salisbury
# 41  Bruno Miguel Borges Fernandes    4-2-3-1              Andy Madley
# 42  Bruno Miguel Borges Fernandes    4-2-3-1           Daniel Siebert
# 43  Bruno Miguel Borges Fernandes    4-1-4-1           Anthony Taylor
# 44                  Harry Maguire    4-2-3-1          Srđan Jovanović
# 45                  Harry Maguire    4-2-3-1           Chris Kavanagh
# 46  Bruno Miguel Borges Fernandes    4-2-3-1           Stuart Attwell
# 47  Bruno Miguel Borges Fernandes    4-2-3-1              John Brooks
# 48                  Harry Maguire    4-2-3-1           Michael Oliver
# 49  Bruno Miguel Borges Fernandes    4-2-3-1             Felix Zwayer
# 50                  Harry Maguire    4-2-3-1             Simon Hooper
# 51                  Harry Maguire    4-2-3-1               Artur Dias
# 52  Bruno Miguel Borges Fernandes    4-2-3-1             Craig Pawson
# 53  Bruno Miguel Borges Fernandes    4-2-3-1           Anthony Taylor
# 54  Bruno Miguel Borges Fernandes    4-1-4-1           Jarred Gillett
# 55  Bruno Miguel Borges Fernandes      4-3-3           Andre Marriner
# 56  Bruno Miguel Borges Fernandes    4-2-3-1             Peter Bankes
# 57  Bruno Miguel Borges Fernandes    4-2-3-1              John Brooks
# 58  Bruno Miguel Borges Fernandes    4-2-3-1           Chris Kavanagh
#
#     Report partita                                               Note
# 0   Report partita                                                NaN
# 1   Report partita                                                NaN
# 2   Report partita                                                NaN
# 3   Report partita                                                NaN
# 4   Report partita                                                NaN
# 5   Report partita                                                NaN
# 6   Report partita                                                NaN
# 7   Report partita                                                NaN
# 8   Report partita                                                NaN
# 9   Report partita                                                NaN
# 10  Report partita                                                NaN
# 11  Report partita                                                NaN
# 12  Report partita                                                NaN
# 13  Report partita                                                NaN
# 14  Report partita                                                NaN
# 15  Report partita                                                NaN
# 16  Report partita                                                NaN
# 17  Report partita                                                NaN
# 18  Report partita                                                NaN
# 19  Report partita                                                NaN
# 20  Report partita                                                NaN
# 21  Report partita                                                NaN
# 22  Report partita                                                NaN
# 23  Report partita                                                NaN
# 24  Report partita                                                NaN
# 25  Report partita                                                NaN
# 26  Report partita                                                NaN
# 27  Report partita                                                NaN
# 28  Report partita                                                NaN
# 29  Report partita                                                NaN
# 30  Report partita                                 Giornata n. 1 di 2
# 31  Report partita                                                NaN
# 32  Report partita     Giornata n. 2 di 2; Manchester Utd qualificato
# 33  Report partita                                                NaN
# 34  Report partita                                                NaN
# 35  Report partita                                                NaN
# 36  Report partita                                 Giornata n. 1 di 2
# 37  Report partita                                                NaN
# 38  Report partita     Giornata n. 2 di 2; Manchester Utd qualificato
# 39  Report partita                                                NaN
# 40  Report partita                                                NaN
# 41  Report partita                                                NaN
# 42  Report partita                                 Giornata n. 1 di 2
# 43  Report partita                                                NaN
# 44  Report partita     Giornata n. 2 di 2; Manchester Utd qualificato
# 45  Report partita                                                NaN
# 46  Report partita                                                NaN
# 47  Report partita                                                NaN
# 48  Report partita                                                NaN
# 49  Report partita                                 Giornata n. 1 di 2
# 50  Report partita                                                NaN
# 51  Report partita            Giornata n. 2 di 2; Sevilla qualificato
# 52  Report partita  Manchester Utd vince ai calci di rigore dopo i...
# 53  Report partita                                                NaN
# 54  Report partita                                                NaN
# 55  Report partita                                                NaN
# 56  Report partita                                                NaN
# 57  Report partita                                                NaN
# 58  Report partita                                                NaN

# %%
# Out:
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/912130727.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ManchesterUtd['Rf'] = pd.Series(x).astype(float)
# /var/folders/mz/zvhyv3212z706hp7196h5hvw0000gn/T/ipykernel_1359/912130727.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ManchesterUtd['Rs'] = pd.Series(y).astype(float)
